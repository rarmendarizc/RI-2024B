# %% [markdown]
# # Trabajo en clases: Web Scrapping
# Nombre: Rossy Armendariz
#
# En base a la página web all recipes, sustraer al menos 200 recetas de las primeras 10 categorias.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL principal de categorías
categories_url = "https://www.allrecipes.com/recipes-a-z-6735880"

# Función para obtener categorías y sus URLs
def get_categories(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Error al acceder a la página de categorías: {response.status_code}")
        return []

    soup = BeautifulSoup(response.content, "html.parser")
    categories = soup.find_all("a", href=True)

    # Filtrar enlaces válidos de categorías
    category_links = {cat.text.strip(): cat['href'] for cat in categories if "/recipes/" in cat['href']}
    return category_links

# Ejecutar el proceso para obtener las categorías
categories = get_categories(categories_url)
if categories:
    # Seleccionar solo las primeras 10 categorías
    selected_categories = dict(list(categories.items())[:10])

    # Guardar en un archivo CSV
    categories_df = pd.DataFrame(list(selected_categories.items()), columns=["Category", "Category URL"])
    categories_df.to_csv("categories_list.csv", index=False)
    print("Archivo 'categories_list.csv' generado con las primeras 10 categorías.")
# Out:
# Archivo 'categories_list.csv' generado con las primeras 10 categorías.

# %% [markdown]
# Obtención de las URLs y IDs de las recetas de las categorías.

# %%
import re
import time
from bs4 import BeautifulSoup
import requests
import pandas as pd

# Cargar categorías desde el archivo generado en el paso 1
categories_df = pd.read_csv("categories_list.csv")
categories = dict(zip(categories_df["Category"], categories_df["Category URL"]))

# Función para extraer recetas de una categoría
def get_recipes_by_category(category_name, category_url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    response = requests.get(category_url, headers=headers)

    # Verificar que la respuesta sea exitosa
    if response.status_code != 200:
        print(f"Error al acceder a la categoría '{category_name}': {response.status_code}")
        return []

    soup = BeautifulSoup(response.content, "html.parser")

    # Buscar todas las tarjetas de recetas
    recipes = soup.find_all("a", href=True)

    # Filtrar solo enlaces válidos de recetas
    recipe_links = []
    for rec in recipes:
        recipe_url = rec['href']

        # Verificar que la URL sea válida para recetas en ambos formatos
        if re.search(r"/recipe/\d+/|/recipe-\d+", recipe_url):
            recipe_links.append(recipe_url)

    return recipe_links

# Procesar todas las categorías para obtener las recetas
recipes_summary = []
recipe_urls = []
for category, category_url in categories.items():
    print(f"Procesando recetas de la categoría: {category}")
    recipe_links = get_recipes_by_category(category, category_url)
    for recipe_url in recipe_links:
        # Extraer ID de la receta desde la URL en ambos formatos
        recipe_id_match = re.search(r"/recipe/(\d+)/|/recipe-(\d+)", recipe_url)
        recipe_id = recipe_id_match.group(1) if recipe_id_match and recipe_id_match.group(1) else recipe_id_match.group(2) if recipe_id_match else "No ID Found"

        # Agregar a resumen de recetas
        recipes_summary.append({
            "Category": category,
            "ID": recipe_id,
            "Recipe URL": recipe_url,
        })

        # Agregar solo la URL a la lista de URLs
        recipe_urls.append({"Recipe URL": recipe_url})

    time.sleep(1)  # Evitar bloqueos

# Guardar los resultados en archivos
# Documento 1: Solo las URLs
recipe_urls_df = pd.DataFrame(recipe_urls)
recipe_urls_df.to_csv("recipe_urls.csv", index=False)
print("Archivo 'recipe_urls.csv' generado con las URLs de las recetas.")

# Documento 2: Categoría, ID y URL
recipes_summary_df = pd.DataFrame(recipes_summary)
recipes_summary_df.to_csv("recipes_summary.csv", index=False)
print("Archivo 'recipes_summary.csv' generado con las categorías, IDs y URLs.")
# Out:
# Procesando recetas de la categoría: Dinners
# Procesando recetas de la categoría: 5-Ingredient Dinners
# Procesando recetas de la categoría: One-Pot Meals
# Procesando recetas de la categoría: Quick & Easy
# Procesando recetas de la categoría: 30-Minute Meals
# Procesando recetas de la categoría: Family Dinners
# Procesando recetas de la categoría: Soups, Stews & Chili
# Procesando recetas de la categoría: Comfort Food
# Procesando recetas de la categoría: Main Dishes
# Procesando recetas de la categoría: Sheet Pan Dinners
# Archivo 'recipe_urls.csv' generado con las URLs de las recetas.
# Archivo 'recipes_summary.csv' generado con las categorías, IDs y URLs.

# %% [markdown]
# Obtención de los siguientes resultados por receta:
# - ID
# - Nombre de la receta
# - Detalle de la receta
# - Ingredientes
# - Preparación
# - URL de la receta

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import re

# Cargar el archivo con las URLs de recetas (incluyendo el ID)
recipe_urls_df = pd.read_csv("recipes_summary.csv")
recipe_data = recipe_urls_df[["ID", "Recipe URL"]].to_dict(orient="records")

# Función para extraer detalles de una receta
def get_recipe_details(recipe_id, recipe_url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    response = requests.get(recipe_url, headers=headers)

    # Verificar que la respuesta sea exitosa
    if response.status_code != 200:
        print(f"Error al acceder a la receta (ID {recipe_id}): {response.status_code}")
        return None

    soup = BeautifulSoup(response.content, "html.parser")

    # Extraer título de la receta
    title_element = soup.find("h1", class_="article-heading text-headline-400")
    title = title_element.text.strip() if title_element else "No Title Found"

    # Extraer descripción de la receta
    description_element = soup.find("p", class_="article-subheading text-body-100")
    description = description_element.text.strip() if description_element else "No Description Found"

    # Extraer ingredientes
    ingredients_section = soup.find_all("li", class_="mm-recipes-structured-ingredients__list-item")
    ingredients = [ingredient.text.strip() for ingredient in ingredients_section]

    # Extraer pasos de preparación
    steps_section = soup.find_all("p", class_="comp mntl-sc-block mntl-sc-block-html")
    steps = [step.text.strip() for step in steps_section]

    return {
        "ID": recipe_id,
        "Recipe Name": title,
        "Description": description,
        "Ingredients": "; ".join(ingredients),
        "Preparation Steps": " ".join(steps),  # Combina todos los pasos en una sola cadena
        "Recipe URL": recipe_url,
    }

# Procesar todas las URLs de recetas para obtener detalles
recipe_details = []
for recipe in recipe_data:
    recipe_id = recipe["ID"]
    recipe_url = recipe["Recipe URL"]
    print(f"Procesando receta (ID {recipe_id}): {recipe_url}")
    details = get_recipe_details(recipe_id, recipe_url)
    if details:
        recipe_details.append(details)
    time.sleep(1)  # Evitar bloqueos

# Guardar los detalles en un archivo CSV
recipe_details_df = pd.DataFrame(recipe_details)
# Asegurarse de que el ID sea la primera columna
recipe_details_df = recipe_details_df[["ID", "Recipe Name", "Description", "Ingredients", "Preparation Steps", "Recipe URL"]]
recipe_details_df.to_csv("recipe_details.csv", index=False)
print("Archivo 'recipe_details.csv' generado con los detalles de las recetas, incluyendo el ID de la receta.")
# Out:
# Procesando receta (ID 212498): https://www.allrecipes.com/recipe/212498/easy-chicken-and-broccoli-alfredo/
# Procesando receta (ID 83646): https://www.allrecipes.com/recipe/83646/corned-beef-roast/
# Procesando receta (ID 158799): https://www.allrecipes.com/recipe/158799/stout-braised-lamb-shanks/
# Procesando receta (ID 8509102): https://www.allrecipes.com/recipe/8509102/chicken-al-pastor/
# Procesando receta (ID 8508920): https://www.allrecipes.com/recipe/8508920/mississippi-chicken/
# Procesando receta (ID 255462): https://www.allrecipes.com/recipe/255462/lasagna-flatbread/
# Procesando receta (ID 245210): https://www.allrecipes.com/recipe/245210/prosciutto-wrapped-pork-tenderloin-with-crispy-sage/
# Procesando receta (ID 215231): https://www.allrecipes.com/recipe/215231/empanadas-beef-turnovers/
# Procesando receta (ID 268494): https://www.allrecipes.com/recipe/268494/basic-air-fryer-hot-dogs/
# Procesando receta (ID 11679): https://www.allrecipes.com/recipe/11679/homemade-mac-and-cheese/
# Procesando receta (ID 14685): https://www.allrecipes.com/recipe/14685/slow-cooker-beef-stew-i/
# Procesando receta (ID 23600): https://www.allrecipes.com/recipe/23600/worlds-best-lasagna/
# Procesando receta (ID 83557): https://www.allrecipes.com/recipe/83557/juicy-roasted-chicken/
# Procesando receta (ID 92462): https://www.allrecipes.com/recipe/92462/slow-cooker-texas-pulled-pork/
# Procesando receta (ID 26317): https://www.allrecipes.com/recipe/26317/chicken-pot-pie-ix/
# Procesando receta (ID 16354): https://www.allrecipes.com/recipe/16354/easy-meatloaf/
# Procesando receta (ID 84270): https://www.allrecipes.com/recipe/84270/slow-cooker-corned-beef-and-cabbage/
# Procesando receta (ID 238691): https://www.allrecipes.com/recipe/238691/simple-macaroni-and-cheese/
# Procesando receta (ID 221958): https://www.allrecipes.com/recipe/221958/chef-johns-perfect-prime-rib/
# Procesando receta (ID 222000): https://www.allrecipes.com/recipe/222000/spaghetti-aglio-e-olio/
# Procesando receta (ID 16310): https://www.allrecipes.com/recipe/16310/corned-beef-and-cabbage-i/
# Procesando receta (ID 6900): https://www.allrecipes.com/recipe/6900/dumplings/
# Procesando receta (ID 24264): https://www.allrecipes.com/recipe/24264/sloppy-joes-ii/
# Procesando receta (ID 21766): https://www.allrecipes.com/recipe/21766/roasted-pork-loin/
# Procesando receta (ID 223042): https://www.allrecipes.com/recipe/223042/chicken-parmesan/
# Procesando receta (ID 262181): https://www.allrecipes.com/recipe/262181/cast-iron-pan-seared-steak-oven-finished/
# Procesando receta (ID 23431): https://www.allrecipes.com/recipe/23431/to-die-for-fettuccine-alfredo/
# Procesando receta (ID 228823): https://www.allrecipes.com/recipe/228823/quick-beef-stir-fry/
# Procesando receta (ID 58942): https://www.allrecipes.com/recipe/58942/absolute-best-liver-and-onions/
# Procesando receta (ID 16346): https://www.allrecipes.com/recipe/16346/maries-easy-slow-cooker-pot-roast/
# Procesando receta (ID 16984): https://www.allrecipes.com/recipe/16984/turkey-in-a-smoker/
# Procesando receta (ID 166160): https://www.allrecipes.com/recipe/166160/juicy-thanksgiving-turkey/
# Procesando receta (ID 14595): https://www.allrecipes.com/recipe/14595/salisbury-steak/
# Procesando receta (ID 83196): https://www.allrecipes.com/recipe/83196/hamburger-jazz/
# Procesando receta (ID 176132): https://www.allrecipes.com/recipe/176132/slow-cooker-buffalo-chicken-sandwiches/
# Procesando receta (ID 8495583): https://www.allrecipes.com/recipe/8495583/pan-fried-pork-chops/
# Procesando receta (ID 245210): https://www.allrecipes.com/recipe/245210/prosciutto-wrapped-pork-tenderloin-with-crispy-sage/
# Procesando receta (ID 222037): https://www.allrecipes.com/recipe/222037/tater-tots-r-casserole/
# Procesando receta (ID 215412): https://www.allrecipes.com/recipe/215412/simple-deep-fried-turkey/
# Procesando receta (ID 240208): https://www.allrecipes.com/recipe/240208/simple-baked-chicken-breasts/
# Procesando receta (ID 235158): https://www.allrecipes.com/recipe/235158/worlds-best-honey-garlic-pork-chops/
# Procesando receta (ID 201934): https://www.allrecipes.com/recipe/201934/pan-seared-tilapia/
# Procesando receta (ID 235153): https://www.allrecipes.com/recipe/235153/easy-baked-chicken-thighs/
# Procesando receta (ID 8495): https://www.allrecipes.com/recipe/8495/chicken-cordon-bleu-i/
# Procesando receta (ID 272293): https://www.allrecipes.com/recipe/272293/fluffy-microwave-scrambled-eggs/
# Procesando receta (ID 23157): https://www.allrecipes.com/recipe/23157/turkey-in-a-bag/
# Procesando receta (ID 244458): https://www.allrecipes.com/recipe/244458/buttered-noodles/
# Procesando receta (ID 228498): https://www.allrecipes.com/recipe/228498/slow-cooker-baby-back-ribs/
# Procesando receta (ID 97621): https://www.allrecipes.com/recipe/97621/foolproof-rib-roast/
# Procesando receta (ID 25473): https://www.allrecipes.com/recipe/25473/the-perfect-basic-burger/
# Procesando receta (ID 236432): https://www.allrecipes.com/recipe/236432/brown-sugar-ham-steak/
# Procesando receta (ID 240522): https://www.allrecipes.com/recipe/240522/easy-rib-eye-roast/
# Procesando receta (ID 14746): https://www.allrecipes.com/recipe/14746/mushroom-pork-chops/
# Procesando receta (ID 231939): https://www.allrecipes.com/recipe/231939/honey-glazed-chicken/
# Procesando receta (ID 214002): https://www.allrecipes.com/recipe/214002/brown-sugar-and-pineapple-glazed-ham/
# Procesando receta (ID 265979): https://www.allrecipes.com/recipe/265979/air-fryer-baked-potatoes/
# Procesando receta (ID 16448): https://www.allrecipes.com/recipe/16448/simple-bbq-ribs/
# Procesando receta (ID 239137): https://www.allrecipes.com/recipe/239137/three-ingredient-baked-chicken-breasts/
# Procesando receta (ID 22538): https://www.allrecipes.com/recipe/22538/baked-salmon-fillets-dijon/
# Procesando receta (ID 228056): https://www.allrecipes.com/recipe/228056/parmesan-crusted-tilapia-fillets/
# Procesando receta (ID 228630): https://www.allrecipes.com/recipe/228630/slow-cooker-pork-and-sauerkraut/
# Procesando receta (ID 260625): https://www.allrecipes.com/recipe/260625/crumbed-chicken-tenderloins-air-fried/
# Procesando receta (ID 229324): https://www.allrecipes.com/recipe/229324/ground-beef-and-cabbage/
# Procesando receta (ID 279463): https://www.allrecipes.com/recipe/279463/old-bay-seasoned-steamed-shrimp/
# Procesando receta (ID 16700): https://www.allrecipes.com/recipe/16700/salsa-chicken/
# Procesando receta (ID 231061): https://www.allrecipes.com/recipe/231061/easy-baked-ham-steaks/
# Procesando receta (ID 246721): https://www.allrecipes.com/recipe/246721/mississippi-roast-slow-cooker-pepperoncini-pot-roast/
# Procesando receta (ID 16824): https://www.allrecipes.com/recipe/16824/easy-breaded-shrimp/
# Procesando receta (ID 85127): https://www.allrecipes.com/recipe/85127/kielbasa-with-peppers-and-potatoes/
# Procesando receta (ID 255305): https://www.allrecipes.com/recipe/255305/simple-chicken-mayo-with-parmesan-and-bread-crumbs/
# Procesando receta (ID 242342): https://www.allrecipes.com/recipe/242342/fiesta-slow-cooker-shredded-chicken-tacos/
# Procesando receta (ID 281393): https://www.allrecipes.com/recipe/281393/smoked-chicken-drumsticks/
# Procesando receta (ID 235851): https://www.allrecipes.com/recipe/235851/how-to-cook-trout/
# Procesando receta (ID 18871): https://www.allrecipes.com/recipe/18871/easy-tuna-casserole/
# Procesando receta (ID 230620): https://www.allrecipes.com/recipe/230620/mayo-chicken/
# Procesando receta (ID 265505): https://www.allrecipes.com/recipe/265505/maple-and-brown-sugar-oatmeal/
# Procesando receta (ID 229032): https://www.allrecipes.com/recipe/229032/parchment-baked-salmon/
# Procesando receta (ID 258426): https://www.allrecipes.com/recipe/258426/pan-fried-shrimp/
# Procesando receta (ID 280052): https://www.allrecipes.com/recipe/280052/bbq-chicken-breasts-in-the-oven/
# Procesando receta (ID 231367): https://www.allrecipes.com/recipe/231367/easy-crispy-baked-chicken/
# Procesando receta (ID 262696): https://www.allrecipes.com/recipe/262696/cheese-omelette/
# Procesando receta (ID 245367): https://www.allrecipes.com/recipe/245367/pan-roasted-chicken-breasts/
# Procesando receta (ID 221071): https://www.allrecipes.com/recipe/221071/simply-roasted-artichokes/
# Procesando receta (ID 279620): https://www.allrecipes.com/recipe/279620/sous-vide-poached-eggs/
# Procesando receta (ID 257865): https://www.allrecipes.com/recipe/257865/easy-chorizo-street-tacos/
# Procesando receta (ID 260193): https://www.allrecipes.com/recipe/260193/instant-pot-salsa-chicken/
# Procesando receta (ID 275553): https://www.allrecipes.com/recipe/275553/breaded-air-fryer-pork-chops/
# Procesando receta (ID 245773): https://www.allrecipes.com/recipe/245773/breakfast-rice-from-japan/
# Procesando receta (ID 277019): https://www.allrecipes.com/recipe/277019/baked-pork-chops-with-cream-of-mushroom-soup/
# Procesando receta (ID 241160): https://www.allrecipes.com/recipe/241160/creamy-cottage-cheese-scrambled-eggs/
# Procesando receta (ID 258968): https://www.allrecipes.com/recipe/258968/scrambled-eggs-with-chorizo/
# Procesando receta (ID 228109): https://www.allrecipes.com/recipe/228109/slow-cooker-chicken-with-stuffing/
# Procesando receta (ID 279624): https://www.allrecipes.com/recipe/279624/instant-pot-ribs-from-frozen/
# Procesando receta (ID 272660): https://www.allrecipes.com/recipe/272660/baked-bbq-chicken-tenders/
# Procesando receta (ID 34870): https://www.allrecipes.com/recipe/34870/chicken-murphy/
# Procesando receta (ID 253157): https://www.allrecipes.com/recipe/253157/weeknight-skillet-slaw/
# Procesando receta (ID 269649): https://www.allrecipes.com/recipe/269649/skillet-chicken-with-sun-dried-tomato-sauce/
# Procesando receta (ID 8541): https://www.allrecipes.com/recipe/8541/carols-arroz-con-pollo/
# Procesando receta (ID 8538585): https://www.allrecipes.com/recipe/8538585/unstuffed-pepper-skillet/
# Procesando receta (ID 8538705): https://www.allrecipes.com/recipe/8538705/tater-tot-hotdish/
# Procesando receta (ID 8526807): https://www.allrecipes.com/recipe/8526807/ground-beef-stroganoff-noodles/
# Procesando receta (ID 8468509): https://www.allrecipes.com/recipe/8468509/one-pot-tortellini-bake/
# Procesando receta (ID 8469279): https://www.allrecipes.com/recipe/8469279/one-pan-tomato-spinach-chicken-pasta/
# Procesando receta (ID 8521894): https://www.allrecipes.com/recipe/8521894/one-pot-lemon-chicken-orzo/
# Procesando receta (ID 212929): https://www.allrecipes.com/recipe/212929/chicken-tinola/
# Procesando receta (ID 76808): https://www.allrecipes.com/recipe/76808/italian-sausage-peppers-and-onions/
# Procesando receta (ID 46822): https://www.allrecipes.com/recipe/46822/indian-chicken-curry-ii/
# Procesando receta (ID 274884): https://www.allrecipes.com/recipe/274884/falafel-with-canned-chickpeas/
# Procesando receta (ID 279903): https://www.allrecipes.com/recipe/279903/garlic-brown-sugar-chicken-thighs/
# Procesando receta (ID 279440): https://www.allrecipes.com/recipe/279440/mexican-rice-and-beans/
# Procesando receta (ID 269004): https://www.allrecipes.com/recipe/269004/one-pot-spaghetti-with-meat-sauce/
# Procesando receta (ID 239047): https://www.allrecipes.com/recipe/239047/one-pan-orecchiette-pasta/
# Procesando receta (ID 282124): https://www.allrecipes.com/recipe/282124/honey-garlic-chicken-thighs/
# Procesando receta (ID 275977): https://www.allrecipes.com/recipe/275977/pork-tenderloin-with-apples-and-onions/
# Procesando receta (ID 257530): https://www.allrecipes.com/recipe/257530/scrambled-eggs-in-a-mug/
# Procesando receta (ID 282524): https://www.allrecipes.com/recipe/282524/one-pot-crispy-chicken-and-rice/
# Procesando receta (ID 275489): https://www.allrecipes.com/recipe/275489/chef-johns-american-goulash/
# Procesando receta (ID 279361): https://www.allrecipes.com/recipe/279361/the-best-baked-rice-and-beans/
# Procesando receta (ID 272834): https://www.allrecipes.com/recipe/272834/easy-homemade-shrimp-fried-rice/
# Procesando receta (ID 276821): https://www.allrecipes.com/recipe/276821/dirty-dirty-rice/
# Procesando receta (ID 258578): https://www.allrecipes.com/recipe/258578/sauteed-shrimp-with-spinach/
# Procesando receta (ID 260471): https://www.allrecipes.com/recipe/260471/loaded-breakfast-skillet/
# Procesando receta (ID 241066): https://www.allrecipes.com/recipe/241066/one-skillet-mexican-quinoa/
# Procesando receta (ID 21560): https://www.allrecipes.com/recipe/21560/skillet-ham-cabbage-and-potatoes/
# Procesando receta (ID 247467): https://www.allrecipes.com/recipe/247467/braised-beef-cheeks/
# Procesando receta (ID 25407): https://www.allrecipes.com/recipe/25407/reuben-casserole/
# Procesando receta (ID 284760): https://www.allrecipes.com/recipe/284760/cinnamon-roll-monkey-bread/
# Procesando receta (ID 8532964): https://www.allrecipes.com/recipe/8532964/air-fryer-tilapia/
# Procesando receta (ID 84214): https://www.allrecipes.com/recipe/84214/blender-hollandaise-sauce/
# Procesando receta (ID 8493351): https://www.allrecipes.com/recipe/8493351/grain-free-broccoli-fritters/
# Procesando receta (ID 8441918): https://www.allrecipes.com/recipe/8441918/skillet-zucchini-and-squash/
# Procesando receta (ID 8499615): https://www.allrecipes.com/recipe/8499615/air-fryer-scrambled-eggs-on-the-go/
# Procesando receta (ID 268494): https://www.allrecipes.com/recipe/268494/basic-air-fryer-hot-dogs/
# Procesando receta (ID 255365): https://www.allrecipes.com/recipe/255365/edible-cookie-dough/
# Procesando receta (ID 238691): https://www.allrecipes.com/recipe/238691/simple-macaroni-and-cheese/
# Procesando receta (ID 6900): https://www.allrecipes.com/recipe/6900/dumplings/
# Procesando receta (ID 8508776): https://www.allrecipes.com/recipe/8508776/homemade-pasta-roni/
# Procesando receta (ID 47015): https://www.allrecipes.com/recipe/47015/quick-and-easy-pancit/
# Procesando receta (ID 23431): https://www.allrecipes.com/recipe/23431/to-die-for-fettuccine-alfredo/
# Procesando receta (ID 228823): https://www.allrecipes.com/recipe/228823/quick-beef-stir-fry/
# Procesando receta (ID 11887): https://www.allrecipes.com/recipe/11887/pesto-pasta/
# Procesando receta (ID 257938): https://www.allrecipes.com/recipe/257938/spicy-thai-basil-chicken-pad-krapow-gai/
# Procesando receta (ID 72068): https://www.allrecipes.com/recipe/72068/chicken-katsu/
# Procesando receta (ID 16311): https://www.allrecipes.com/recipe/16311/simple-beef-stroganoff/
# Procesando receta (ID 8887): https://www.allrecipes.com/recipe/8887/chicken-marsala/
# Procesando receta (ID 201934): https://www.allrecipes.com/recipe/201934/pan-seared-tilapia/
# Procesando receta (ID 230857): https://www.allrecipes.com/recipe/230857/easy-tuna-patties/
# Procesando receta (ID 132358): https://www.allrecipes.com/recipe/132358/easy-garlic-lemon-scallops/
# Procesando receta (ID 15559): https://www.allrecipes.com/recipe/15559/black-beans-and-rice/
# Procesando receta (ID 9025): https://www.allrecipes.com/recipe/9025/bourbon-chicken/
# Procesando receta (ID 20225): https://www.allrecipes.com/recipe/20225/creamed-chipped-beef-on-toast/
# Procesando receta (ID 244458): https://www.allrecipes.com/recipe/244458/buttered-noodles/
# Procesando receta (ID 140930): https://www.allrecipes.com/recipe/140930/southern-fried-catfish/
# Procesando receta (ID 272858): https://www.allrecipes.com/recipe/272858/air-fryer-chicken-thighs/
# Procesando receta (ID 232906): https://www.allrecipes.com/recipe/232906/simple-broiled-haddock/
# Procesando receta (ID 12011): https://www.allrecipes.com/recipe/12011/easy-lasagna-ii/
# Procesando receta (ID 21306): https://www.allrecipes.com/recipe/21306/fish-in-foil/
# Procesando receta (ID 269500): https://www.allrecipes.com/recipe/269500/creamy-garlic-pasta/
# Procesando receta (ID 220597): https://www.allrecipes.com/recipe/220597/simple-garlic-shrimp/
# Procesando receta (ID 46982): https://www.allrecipes.com/recipe/46982/pesto-pasta-with-chicken/
# Procesando receta (ID 8571): https://www.allrecipes.com/recipe/8571/blackened-chicken/
# Procesando receta (ID 11951): https://www.allrecipes.com/recipe/11951/linguine-with-clam-sauce/
# Procesando receta (ID 100195): https://www.allrecipes.com/recipe/100195/baked-haddock/
# Procesando receta (ID 231939): https://www.allrecipes.com/recipe/231939/honey-glazed-chicken/
# Procesando receta (ID 16305): https://www.allrecipes.com/recipe/16305/sweet-and-sour-meatballs-ii/
# Procesando receta (ID 93234): https://www.allrecipes.com/recipe/93234/honey-walnut-shrimp/
# Procesando receta (ID 14554): https://www.allrecipes.com/recipe/14554/sirloin-steak-with-garlic-butter/
# Procesando receta (ID 134483): https://www.allrecipes.com/recipe/134483/chicago-style-hot-dog/
# Procesando receta (ID 189058): https://www.allrecipes.com/recipe/189058/super-simple-salmon/
# Procesando receta (ID 12775): https://www.allrecipes.com/recipe/12775/spicy-grilled-shrimp/
# Procesando receta (ID 236814): https://www.allrecipes.com/recipe/236814/baked-fresh-rainbow-trout/
# Procesando receta (ID 155375): https://www.allrecipes.com/recipe/155375/crab-legs-with-garlic-butter-sauce/
# Procesando receta (ID 244950): https://www.allrecipes.com/recipe/244950/baked-chicken-schnitzel/
# Procesando receta (ID 76659): https://www.allrecipes.com/recipe/76659/heavenly-halibut/
# Procesando receta (ID 231549): https://www.allrecipes.com/recipe/231549/baked-flounder-with-panko-and-parmesan/
# Procesando receta (ID 220164): https://www.allrecipes.com/recipe/220164/classic-cuban-style-picadillo/
# Procesando receta (ID 239428): https://www.allrecipes.com/recipe/239428/crispy-panko-chicken-breasts/
# Procesando receta (ID 82347): https://www.allrecipes.com/recipe/82347/best-ever-crab-cakes/
# Procesando receta (ID 69471): https://www.allrecipes.com/recipe/69471/baby-spinach-omelet/
# Procesando receta (ID 26286): https://www.allrecipes.com/recipe/26286/quick-and-easy-chicken-spaghetti/
# Procesando receta (ID 22538): https://www.allrecipes.com/recipe/22538/baked-salmon-fillets-dijon/
# Procesando receta (ID 240130): https://www.allrecipes.com/recipe/240130/scrumptious-salmon-cakes/
# Procesando receta (ID 218562): https://www.allrecipes.com/recipe/218562/super-easy-chicken-and-dumplings/
# Procesando receta (ID 71698): https://www.allrecipes.com/recipe/71698/sesame-seared-tuna/
# Procesando receta (ID 228056): https://www.allrecipes.com/recipe/228056/parmesan-crusted-tilapia-fillets/
# Procesando receta (ID 38028): https://www.allrecipes.com/recipe/38028/blackened-fish/
# Procesando receta (ID 216757): https://www.allrecipes.com/recipe/216757/savory-sea-scallops-and-angel-hair-pasta/
# Procesando receta (ID 127500): https://www.allrecipes.com/recipe/127500/japanese-style-deep-fried-shrimp/
# Procesando receta (ID 220751): https://www.allrecipes.com/recipe/220751/quick-chicken-piccata/
# Procesando receta (ID 20107): https://www.allrecipes.com/recipe/20107/beer-batter-fish-made-great/
# Procesando receta (ID 280935): https://www.allrecipes.com/recipe/280935/air-fryer-tilapia-with-fresh-lemon-pepper/
# Procesando receta (ID 36487): https://www.allrecipes.com/recipe/36487/blackened-salmon-fillets/
# Procesando receta (ID 276006): https://www.allrecipes.com/recipe/276006/air-fryer-lobster-tails-with-lemon-garlic-butter/
# Procesando receta (ID 219431): https://www.allrecipes.com/recipe/219431/parmesan-crusted-chicken/
# Procesando receta (ID 256349): https://www.allrecipes.com/recipe/256349/baked-fish-fillets/
# Procesando receta (ID 260625): https://www.allrecipes.com/recipe/260625/crumbed-chicken-tenderloins-air-fried/
# Procesando receta (ID 279463): https://www.allrecipes.com/recipe/279463/old-bay-seasoned-steamed-shrimp/
# Procesando receta (ID 163370): https://www.allrecipes.com/recipe/163370/shrimp-egg-foo-young/
# Procesando receta (ID 217339): https://www.allrecipes.com/recipe/217339/crispy-baked-walleye/
# Procesando receta (ID 19508): https://www.allrecipes.com/recipe/19508/shrimp-scampi/
# Procesando receta (ID 99742): https://www.allrecipes.com/recipe/99742/steamed-lobster-tails/
# Procesando receta (ID 241630): https://www.allrecipes.com/recipe/241630/creamy-beef-tips-with-egg-noodles/
# Procesando receta (ID 229210): https://www.allrecipes.com/recipe/229210/fiesta-tater-tot-casserole/
# Procesando receta (ID 23874): https://www.allrecipes.com/recipe/23874/catherines-spicy-chicken-soup/
# Procesando receta (ID 11751): https://www.allrecipes.com/recipe/11751/simple-mac-and-cheese/
# Procesando receta (ID 231080): https://www.allrecipes.com/recipe/231080/hidden-veggie-meatloaf/
# Procesando receta (ID 222586): https://www.allrecipes.com/recipe/222586/scrambled-egg-muffins/
# Procesando receta (ID 255462): https://www.allrecipes.com/recipe/255462/lasagna-flatbread/
# Procesando receta (ID 45396): https://www.allrecipes.com/recipe/45396/easy-pancakes/
# Procesando receta (ID 10294): https://www.allrecipes.com/recipe/10294/the-best-lemon-bars/
# Procesando receta (ID 10549): https://www.allrecipes.com/recipe/10549/best-brownies/
# Procesando receta (ID 42719): https://www.allrecipes.com/recipe/42719/banana-muffins-ii/
# Procesando receta (ID 24445): https://www.allrecipes.com/recipe/24445/chewy-chocolate-chip-oatmeal-cookies/
# Procesando receta (ID 11887): https://www.allrecipes.com/recipe/11887/pesto-pasta/
# Procesando receta (ID 223597): https://www.allrecipes.com/recipe/223597/old-fashioned-potato-cakes/
# Procesando receta (ID 39544): https://www.allrecipes.com/recipe/39544/garden-fresh-tomato-soup/
# Procesando receta (ID 150344): https://www.allrecipes.com/recipe/150344/corn-muffin-pancakes/
# Procesando receta (ID 72159): https://www.allrecipes.com/recipe/72159/easy-baked-oatmeal/
# Procesando receta (ID 63959): https://www.allrecipes.com/recipe/63959/magic-cookie-bars-from-eagle-brand/
# Procesando receta (ID 21659): https://www.allrecipes.com/recipe/21659/chicken-quesadillas/
# Procesando receta (ID 230857): https://www.allrecipes.com/recipe/230857/easy-tuna-patties/
# Procesando receta (ID 20808): https://www.allrecipes.com/recipe/20808/kettle-corn/
# Procesando receta (ID 25224): https://www.allrecipes.com/recipe/25224/classic-bran-muffins/
# Procesando receta (ID 244447): https://www.allrecipes.com/recipe/244447/two-ingredient-pizza-dough/
# Procesando receta (ID 6714): https://www.allrecipes.com/recipe/6714/banana-oat-muffins/
# Procesando receta (ID 228115): https://www.allrecipes.com/recipe/228115/2-minute-cheese-quesadillas/
# Procesando receta (ID 9889): https://www.allrecipes.com/recipe/9889/seven-layer-bars/
# Procesando receta (ID 8849): https://www.allrecipes.com/recipe/8849/baked-chicken-nuggets/
# Procesando receta (ID 17377): https://www.allrecipes.com/recipe/17377/chocolate-cupcakes/
# Procesando receta (ID 9999): https://www.allrecipes.com/recipe/9999/peanut-butter-bars-i/
# Procesando receta (ID 233985): https://www.allrecipes.com/recipe/233985/chocolate-protein-balls/
# Procesando receta (ID 136476): https://www.allrecipes.com/recipe/136476/easy-french-dip-sandwiches/
# Procesando receta (ID 187850): https://www.allrecipes.com/recipe/187850/egg-in-a-hole/
# Procesando receta (ID 25832): https://www.allrecipes.com/recipe/25832/cream-cheese-squares/
# Procesando receta (ID 232375): https://www.allrecipes.com/recipe/232375/natashas-chicken-burgers/
# Procesando receta (ID 16239): https://www.allrecipes.com/recipe/16239/easy-slow-cooker-french-dip/
# Procesando receta (ID 86649): https://www.allrecipes.com/recipe/86649/fast-english-muffin-pizzas/
# Procesando receta (ID 258468): https://www.allrecipes.com/recipe/258468/beef-stroganoff-for-instant-pot/
# Procesando receta (ID 221923): https://www.allrecipes.com/recipe/221923/japanese-tamago-egg/
# Procesando receta (ID 44975): https://www.allrecipes.com/recipe/44975/easy-pizza-sauce-iii/
# Procesando receta (ID 89539): https://www.allrecipes.com/recipe/89539/slow-cooker-chicken-tortilla-soup/
# Procesando receta (ID 68436): https://www.allrecipes.com/recipe/68436/vegan-brownies/
# Procesando receta (ID 8847): https://www.allrecipes.com/recipe/8847/baked-honey-mustard-chicken/
# Procesando receta (ID 10707): https://www.allrecipes.com/recipe/10707/mmm-mmm-better-brownies/
# Procesando receta (ID 8944): https://www.allrecipes.com/recipe/8944/easy-shake-and-bake-chicken/
# Procesando receta (ID 245914): https://www.allrecipes.com/recipe/245914/baked-oatmeal-breakfast-bars/
# Procesando receta (ID 14172): https://www.allrecipes.com/recipe/14172/caesar-salad-supreme/
# Procesando receta (ID 260109): https://www.allrecipes.com/recipe/260109/instant-pot-chicken-cacciatore/
# Procesando receta (ID 13564): https://www.allrecipes.com/recipe/13564/pecan-pie-bars-i/
# Procesando receta (ID 218493): https://www.allrecipes.com/recipe/218493/melindas-porcupine-meatballs/
# Procesando receta (ID 223462): https://www.allrecipes.com/recipe/223462/simple-strawberry-syrup/
# Procesando receta (ID 8389): https://www.allrecipes.com/recipe/8389/wacky-cake-viii/
# Procesando receta (ID 14831): https://www.allrecipes.com/recipe/14831/dill-dip-iii/
# Procesando receta (ID 10177): https://www.allrecipes.com/recipe/10177/blonde-brownies-i/
# Procesando receta (ID 11504): https://www.allrecipes.com/recipe/11504/chewy-peanut-butter-brownies/
# Procesando receta (ID 240476): https://www.allrecipes.com/recipe/240476/turkey-tom-kha-gai/
# Procesando receta (ID 244323): https://www.allrecipes.com/recipe/244323/thanksgiving-turkey-congee/
# Procesando receta (ID 255022): https://www.allrecipes.com/recipe/255022/turkey-matzo-ball-soup/
# Procesando receta (ID 274492): https://www.allrecipes.com/recipe/274492/golden-state-gazpacho/
# Procesando receta (ID 12477): https://www.allrecipes.com/recipe/12477/steak-and-kidney-pie-ii/
# Procesando receta (ID 8533467): https://www.allrecipes.com/recipe/8533467/cheddar-bay-biscuit-cobbler/
# Procesando receta (ID 8472782): https://www.allrecipes.com/recipe/8472782/frito-chicken-casserole/
# Procesando receta (ID 8509348): https://www.allrecipes.com/recipe/8509348/king-ranch-chicken-and-fresh-veggie-casserole/
# Procesando receta (ID 8506346): https://www.allrecipes.com/recipe/8506346/chef-johns-chicken-fricassee/
# Procesando receta (ID 215231): https://www.allrecipes.com/recipe/215231/empanadas-beef-turnovers/
# Procesando receta (ID 11679): https://www.allrecipes.com/recipe/11679/homemade-mac-and-cheese/
# Procesando receta (ID 85337): https://www.allrecipes.com/recipe/85337/microwave-baked-potato/
# Procesando receta (ID 24771): https://www.allrecipes.com/recipe/24771/basic-mashed-potatoes/
# Procesando receta (ID 15925): https://www.allrecipes.com/recipe/15925/creamy-au-gratin-potatoes/
# Procesando receta (ID 14685): https://www.allrecipes.com/recipe/14685/slow-cooker-beef-stew-i/
# Procesando receta (ID 23600): https://www.allrecipes.com/recipe/23600/worlds-best-lasagna/
# Procesando receta (ID 18379): https://www.allrecipes.com/recipe/18379/best-green-bean-casserole/
# Procesando receta (ID 26317): https://www.allrecipes.com/recipe/26317/chicken-pot-pie-ix/
# Procesando receta (ID 16354): https://www.allrecipes.com/recipe/16354/easy-meatloaf/
# Procesando receta (ID 222000): https://www.allrecipes.com/recipe/222000/spaghetti-aglio-e-olio/
# Procesando receta (ID 24264): https://www.allrecipes.com/recipe/24264/sloppy-joes-ii/
# Procesando receta (ID 24332): https://www.allrecipes.com/recipe/24332/ultimate-twice-baked-potatoes/
# Procesando receta (ID 23431): https://www.allrecipes.com/recipe/23431/to-die-for-fettuccine-alfredo/
# Procesando receta (ID 57783): https://www.allrecipes.com/recipe/57783/emilys-famous-hash-browns/
# Procesando receta (ID 74360): https://www.allrecipes.com/recipe/74360/the-best-meatloaf-ive-ever-made/
# Procesando receta (ID 216888): https://www.allrecipes.com/recipe/216888/good-new-orleans-creole-gumbo/
# Procesando receta (ID 26460): https://www.allrecipes.com/recipe/26460/quick-and-easy-chicken-noodle-soup/
# Procesando receta (ID 17219): https://www.allrecipes.com/recipe/17219/best-tuna-casserole/
# Procesando receta (ID 31848): https://www.allrecipes.com/recipe/31848/jambalaya/
# Procesando receta (ID 11758): https://www.allrecipes.com/recipe/11758/baked-ziti-i/
# Procesando receta (ID 18465): https://www.allrecipes.com/recipe/18465/gnocchi-i/
# Procesando receta (ID 229960): https://www.allrecipes.com/recipe/229960/shrimp-scampi-with-pasta/
# Procesando receta (ID 15985): https://www.allrecipes.com/recipe/15985/grandmas-corn-pudding/
# Procesando receta (ID 13883): https://www.allrecipes.com/recipe/13883/manicotti/
# Procesando receta (ID 16311): https://www.allrecipes.com/recipe/16311/simple-beef-stroganoff/
# Procesando receta (ID 223597): https://www.allrecipes.com/recipe/223597/old-fashioned-potato-cakes/
# Procesando receta (ID 151593): https://www.allrecipes.com/recipe/151593/campbells-tuna-noodle-casserole/
# Procesando receta (ID 54679): https://www.allrecipes.com/recipe/54679/perfect-baked-potato/
# Procesando receta (ID 14089): https://www.allrecipes.com/recipe/14089/potato-pancakes-i/
# Procesando receta (ID 279848): https://www.allrecipes.com/recipe/279848/chicken-broccoli-and-cheddar-casserole/
# Procesando receta (ID 215447): https://www.allrecipes.com/recipe/215447/dads-leftover-turkey-pot-pie/
# Procesando receta (ID 71803): https://www.allrecipes.com/recipe/71803/quick-and-easy-home-fries/
# Procesando receta (ID 25490): https://www.allrecipes.com/recipe/25490/broccoli-rice-cheese-and-chicken-casserole/
# Procesando receta (ID 222582): https://www.allrecipes.com/recipe/222582/baked-spaghetti/
# Procesando receta (ID 280246): https://www.allrecipes.com/recipe/280246/chef-johns-tuna-noodle-casserole/
# Procesando receta (ID 14647): https://www.allrecipes.com/recipe/14647/oven-barbecued-beef-brisket-i/
# Procesando receta (ID 245584): https://www.allrecipes.com/recipe/245584/crispy-turkey-flautas/
# Procesando receta (ID 235159): https://www.allrecipes.com/recipe/235159/how-to-make-turkey-manicotti/
# Procesando receta (ID 8400263): https://www.allrecipes.com/recipe/8400263/sheet-pan-meatloaf/
# Procesando receta (ID 8544430): https://www.allrecipes.com/recipe/8544430/sheet-balsamic-pork-tenderloin-with-rainbow-vegetables/
# Procesando receta (ID 8527068): https://www.allrecipes.com/recipe/8527068/sheet-pan-new-orleans-style-shrimp/
# Procesando receta (ID 242352): https://www.allrecipes.com/recipe/242352/greek-lemon-chicken-and-potatoes/
# Procesando receta (ID 71387): https://www.allrecipes.com/recipe/71387/best-salmon-bake/
# Procesando receta (ID 236110): https://www.allrecipes.com/recipe/236110/baked-chicken-breasts-and-vegetables/
# Procesando receta (ID 255936): https://www.allrecipes.com/recipe/255936/chicken-sausage-peppers-and-potatoes/
# Procesando receta (ID 21009): https://www.allrecipes.com/recipe/21009/sheet-pan-roasted-vegetables/
# Procesando receta (ID 255038): https://www.allrecipes.com/recipe/255038/sheet-pan-chicken-fajitas/
# Procesando receta (ID 281435): https://www.allrecipes.com/recipe/281435/sheet-pan-seafood-boil/
# Procesando receta (ID 268999): https://www.allrecipes.com/recipe/268999/mediterranean-chicken-sheet-pan-dinner/
# Procesando receta (ID 268843): https://www.allrecipes.com/recipe/268843/sheet-pan-shrimp-and-sausage-bake/
# Procesando receta (ID 262162): https://www.allrecipes.com/recipe/262162/sheet-pan-salmon-and-bell-pepper-dinner/
# Procesando receta (ID 274966): https://www.allrecipes.com/recipe/274966/sheet-pan-parmesan-chicken-and-veggies/
# Procesando receta (ID 242402): https://www.allrecipes.com/recipe/242402/greek-lemon-chicken-and-potato-bake/
# Procesando receta (ID 269152): https://www.allrecipes.com/recipe/269152/shrimp-and-vegetable-sheet-pan-dinner/
# Procesando receta (ID 283432): https://www.allrecipes.com/recipe/283432/everything-salmon-sheet-pan-dinner/
# Procesando receta (ID 269230): https://www.allrecipes.com/recipe/269230/sheet-pan-smoked-sausage-apple-and-root-veggie-dinner/
# Procesando receta (ID 280868): https://www.allrecipes.com/recipe/280868/sweet-and-spicy-jerk-shrimp/
# Procesando receta (ID 261600): https://www.allrecipes.com/recipe/261600/sheet-pan-lemon-butter-garlic-shrimp-with-asparagus/
# Procesando receta (ID 269330): https://www.allrecipes.com/recipe/269330/sheet-pan-roasted-mediterranean-vegetables/
# Procesando receta (ID 77489): https://www.allrecipes.com/recipe/77489/crispy-rosemary-chicken-and-fries/
# Procesando receta (ID 263602): https://www.allrecipes.com/recipe/263602/sheet-pan-vegan-roasted-brussels-sprouts-and-butternut-squash/
# Procesando receta (ID 283433): https://www.allrecipes.com/recipe/283433/sheet-pan-beef-fajitas/
# Procesando receta (ID 26611): https://www.allrecipes.com/recipe/26611/sheet-pan-ground-beef-potato-and-carrot-dinner/
# Procesando receta (ID 281136): https://www.allrecipes.com/recipe/281136/easy-sheet-pan-beef-bulgogi/
# Procesando receta (ID 256529): https://www.allrecipes.com/recipe/256529/stuffed-chicken-thighs-with-roasted-potatoes-and-carrots/
# Procesando receta (ID 258572): https://www.allrecipes.com/recipe/258572/sheet-pan-shrimp-fajitas/
# Procesando receta (ID 256016): https://www.allrecipes.com/recipe/256016/dijon-pork-with-apples-and-cabbage/
# Procesando receta (ID 280867): https://www.allrecipes.com/recipe/280867/maple-roasted-chicken-thighs/
# Procesando receta (ID 283301): https://www.allrecipes.com/recipe/283301/sheet-pan-roasted-chicken-thighs-with-brussels-sprouts/
# Procesando receta (ID 261609): https://www.allrecipes.com/recipe/261609/basic-sheet-pan-chicken-sausage-and-roasted-cabbage/
# Procesando receta (ID 262533): https://www.allrecipes.com/recipe/262533/chicken-apple-and-brussels-sprout-sheet-pan-dinner/
# Procesando receta (ID 241287): https://www.allrecipes.com/recipe/241287/baked-italian-chicken-dinner/
# Procesando receta (ID 266136): https://www.allrecipes.com/recipe/266136/sheet-pan-chicken-with-mozzarella-pesto-and-broccoli/
# Procesando receta (ID 281413): https://www.allrecipes.com/recipe/281413/easy-sheet-pan-greek-chicken/
# Procesando receta (ID 268995): https://www.allrecipes.com/recipe/268995/vegetarian-sheet-pan-dinner-with-chickpeas-and-veggies/
# Procesando receta (ID 261598): https://www.allrecipes.com/recipe/261598/easy-one-pan-pork-and-squash-dinner/
# Procesando receta (ID 261839): https://www.allrecipes.com/recipe/261839/baked-chicken-thighs-coated-with-corn-flake-crumbs/
# Procesando receta (ID 261608): https://www.allrecipes.com/recipe/261608/easy-vegan-sheet-pan-roasted-cauliflower-tomatoes-and-garbanzo-beans/
# Procesando receta (ID 236306): https://www.allrecipes.com/recipe/236306/roasted-chicken-with-lemon-and-rosemary/
# Archivo 'recipe_details.csv' generado con los detalles de las recetas, incluyendo el ID de la receta.

# %% [markdown]
# ## Preprocesamiento de los datos

# %%
import csv
import string
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import nltk

# Descargar las stopwords de NLTK si no lo has hecho antes
nltk.download('stopwords')

# Configuración
archivo_original = './recipe_details.csv'
archivo_salida = 'recipe_details_procesado.csv'
stop_words = set(stopwords.words('english'))  # Cambia a 'english' si es necesario
stemmer = SnowballStemmer('english')  # Cambia el idioma a 'english' si es necesario

# Función para procesar el texto
def procesar_texto(texto):
    # Convertir a minúsculas
    texto = texto.lower()
    # Eliminar signos de puntuación
    texto = texto.translate(str.maketrans('', '', string.punctuation))
    # Eliminar stopwords y aplicar stemming
    palabras = texto.split()
    palabras_procesadas = [
        stemmer.stem(palabra) for palabra in palabras if palabra not in stop_words
    ]
    return ' '.join(palabras_procesadas)

# Leer el archivo original y procesar
with open(archivo_original, mode='r', encoding='utf-8') as entrada:
    lector = csv.reader(entrada)
    filas_procesadas = []

    # Procesar la primera fila (nombres de las columnas) sin modificaciones
    encabezados = next(lector)  # Obtener la primera fila
    filas_procesadas.append(encabezados)  # Agregarla directamente al resultado

    # Procesar las demás filas
    for fila in lector:
        fila_procesada = [procesar_texto(celda) for celda in fila]
        filas_procesadas.append(fila_procesada)

# Escribir el archivo procesado
with open(archivo_salida, mode='w', encoding='utf-8', newline='') as salida:
    escritor = csv.writer(salida)
    escritor.writerows(filas_procesadas)

print(f"El archivo procesado ha sido guardado como '{archivo_salida}'.")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# El archivo procesado ha sido guardado como 'recipe_details_procesado.csv'.

# %% [markdown]
# Instalación de las bibliotecas necesarias para utilizar FAISS para la recuperación.

# %%
# %pip install sentence-transformers faiss-cpu
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.3.1)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.9.0.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.47.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.27.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)
# Downloading faiss_cpu-1.9.0.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 53.2 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.9.0.post1

# %% [markdown]
# Creación de embeddings, índice de FAISS y la función de búsqueda con FAISS.

# %%
import pandas as pd
import numpy as np
import faiss
from tqdm import tqdm
from sentence_transformers import SentenceTransformer

# Cargar los archivos CSV
preprocessed_df = pd.read_csv("recipe_details_procesado.csv")  # Archivo preprocesado
original_df = pd.read_csv("recipe_details.csv")  # Archivo sin preprocesar
original_df.columns = ["ID", "Recipe Name", "Description", "Ingredients", "Preparation Steps", "Recipe URL"]

# Asegurar que los IDs sean tratados como strings
preprocessed_df["ID"] = preprocessed_df["ID"].astype(str)
original_df["ID"] = original_df["ID"].astype(str)

# Modelo de embeddings
print("Cargando el modelo de embeddings...")
modelo_embeddings = SentenceTransformer('all-MiniLM-L6-v2')

# Generar embeddings a partir de las descripciones procesadas
print("Generando embeddings...")
descripciones = preprocessed_df["Description"].tolist()
embeddings = modelo_embeddings.encode(descripciones, show_progress_bar=True)

# Crear índice FAISS
dimension = embeddings.shape[1]  # Dimensión de los vectores
index = faiss.IndexFlatL2(dimension)  # Índice con métrica de distancia Euclidiana
index.add(embeddings)  # Agregar los embeddings al índice

# Confirmar que los vectores se han agregado correctamente
print(f"Total de vectores en el índice: {index.ntotal}")

# Función para realizar búsquedas con FAISS
def realizar_busqueda_faiss(consulta, num_resultados=5):
    # Generar el embedding de la consulta
    consulta_embedding = modelo_embeddings.encode([consulta])

    # Buscar los vecinos más cercanos
    distancias, indices = index.search(consulta_embedding, num_resultados)

    # Recuperar resultados del archivo preprocesado
    resultados_preprocesados = preprocessed_df.iloc[indices[0]].copy()
    resultados_preprocesados["Distancia"] = distancias[0]

    # Crear una lista para almacenar los resultados originales
    resultados_completos = []

    # Buscar los datos originales usando los IDs
    for _, fila in resultados_preprocesados.iterrows():
        receta_original = original_df[original_df["ID"] == fila["ID"]]
        if not receta_original.empty:
            resultados_completos.append({
                "ID": fila["ID"],
                "Recipe Name": receta_original.iloc[0]["Recipe Name"],
                "Description": receta_original.iloc[0]["Description"],
                "Ingredients": receta_original.iloc[0]["Ingredients"],
                "Preparation Steps": receta_original.iloc[0]["Preparation Steps"],
                "Recipe URL": receta_original.iloc[0]["Recipe URL"],
                "Distancia": fila["Distancia"]
            })

    # Convertir los resultados completos en un DataFrame
    resultados_df = pd.DataFrame(resultados_completos)
    return resultados_df
# Out:
# Cargando el modelo de embeddings...
# Generando embeddings...
# Batches:   0%|          | 0/11 [00:00<?, ?it/s]
# Total de vectores en el índice: 344

# %% [markdown]
# Ejemplo práctico de la consulta mediante la recuperación FAISS:

# %%
# Ejemplo práctico de consulta
consulta = "chicken"
print("\nResultados de la consulta:")
resultados = realizar_busqueda_faiss(consulta, num_resultados=5)

# Mostrar los resultados
print(resultados)
# Out:
# Resultados de la consulta:
#        ID                              Recipe Name  \
# 0  220751                    Quick Chicken Piccata
# 1  236306                    Lemon-Roasted Chicken
# 2  260625  Crumbed Chicken Tenderloins (Air Fried)
# 3  260625  Crumbed Chicken Tenderloins (Air Fried)
# 4  176132   Slow Cooker Buffalo Chicken Sandwiches
#
#                                          Description  \
# 0  Chicken piccata is super quick and easy to mak...
# 1  This lemon-roasted chicken is our go-to baked ...
# 2  These air fryer chicken tenderloins beat chick...
# 3  These air fryer chicken tenderloins beat chick...
# 4  This crockpot Buffalo chicken is great for hea...
#
#                                          Ingredients  \
# 0  4  skinless, boneless chicken breast halves; c...
# 1  1 whole chicken, cut into 8 pieces; 1 onion, c...
# 2  1 large egg; ½ cup dry bread crumbs; 2 tablesp...
# 3  1 large egg; ½ cup dry bread crumbs; 2 tablesp...
# 4  4  skinless, boneless chicken breast halves; 1...
#
#                                    Preparation Steps  \
# 0  Place chicken breasts between 2 sheets of heav...
# 1  Preheat the oven to 450 degrees F (230 degrees...
# 2  Gather all ingredients. Preheat an air fryer t...
# 3  Gather all ingredients. Preheat an air fryer t...
# 4  Gather all ingredients. Place chicken breasts ...
#
#                                           Recipe URL  Distancia
# 0  https://www.allrecipes.com/recipe/220751/quick...   0.882559
# 1  https://www.allrecipes.com/recipe/236306/roast...   0.897243
# 2  https://www.allrecipes.com/recipe/260625/crumb...   0.973646
# 3  https://www.allrecipes.com/recipe/260625/crumb...   0.973646
# 4  https://www.allrecipes.com/recipe/176132/slow-...   0.973845
